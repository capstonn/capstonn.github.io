# %% [markdown]
# <a href="https://colab.research.google.com/github/capstonn/capstonn.github.io/blob/main/MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('gdrive', force_remount=True)
# Out:
# Mounted at gdrive

# %%
root_dir = '/content/gdrive/pytorch_test/mnist'

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

from matplotlib import pyplot as plt

# %%
is_cuda = torch.cuda.is_available()
is_cuda
# Out:
# True

# %%
device = torch.device('cuda' if is_cuda else 'cpu')
device
# Out:
# device(type='cuda')

# %%
batch_size = 50
epoch_num = 15
learning_rate = 0.0001

# %%
train_data = datasets.MNIST(root = root_dir+'./data', train=True, download=True,
                            transform=transforms.ToTensor())
test_data = datasets.MNIST(root = root_dir+'./data', train=False,
                           transform=transforms.ToTensor())
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-15-2f36a7bb02e8> in <cell line: 1>()
# ----> 1 train_data = datasets.MNIST(root = root_dir+'./data', train=True, download=True,
#       2                             transform=transforms.ToTensor())
#       3 test_data = datasets.MNIST(root = root_dir+'./data', train=False,
#       4                            transform=transforms.ToTensor())
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/mnist.py in __init__(self, root, train, transform, target_transform, download)
#      98
#      99         if download:
# --> 100             self.download()
#     101
#     102         if not self._check_exists():
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/mnist.py in download(self)
#     178             return
#     179
# --> 180         os.makedirs(self.raw_folder, exist_ok=True)
# ...

# %%
print(len(train_data), len(test_data))

# %%
type(train_data[0])

# %%
image, label = train_data[0]

# %%
image.shape

# %%
plt.imshow(image.squeeze(), cmap='gray')
plt.title('label: %s' % label)
plt.show()

# %%
train_loader = torch.utils.data.DataLoader(dataset = train_data,
                                           batch_size = batch_size,
                                           shuffle = True)
test_loader = torch.utils.data.DataLoader(dataset = test_data,
                                           batch_size = batch_size,
                                           shuffle = True)

first_batch = train_loader.__iter__().__next__()
print(f"{'name':15s} | {'type':<25s} | {'size'}")
print(f"{'num of Batch':15s} | {'':<25s} | {len(train_loader)}")
print(f"{'first_batch':15s} | {str(type(first_batch)):<25s} | {len(first_batch)}")
print(f"{'first_batch[0]':15s} | {str(type(first_batch[0])):<25s} | {first_batch[0].shape}")
print(f"{'first_batch[1]':15s} | {str(type(first_batch[1])):<25s} | {first_batch[1].shape}")

# %%
class CNN(nn.Module):
  def __init__(self):
    super(CNN, self).__init__()
    self.conv1 = nn.Conv2d(1, 32, 3, 1)
    self.conv2 = nn.Conv2d(32, 64, 3, 1)
    self.dropout1 = nn.Dropout2d(0.25)
    self.dropout2 = nn.Dropout2d(0.5)
    self.fc1 = nn.Linear(9216, 128)
    self.fc2 = nn.Linear(128, 10)

  def forward(self, x):
    x = self.conv1(x)
    x = F.relu(x)
    x = self.conv2(x)
    x = F.relu(x)
    x = F.max_pool2d(x, 2)
    x = self.dropout1(x)
    x = torch.flatten(x, 1)
    x = self.fc1(x)
    x = F.relu(x)
    x = self.dropout2(x)
    x = self.fc2(x)
    output = F.log_softmax(x, dim=1)
    return output

# %%
model = CNN().to(device)
optimizer = optim.Adam(model.parameters(), lr = learning_rate)
criterion = nn.CrossEntropyLoss()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-7d10167d6745> in <cell line: 1>()
# ----> 1 model = CNN().to(device)
#       2 optimizer = optim.Adam(model.parameters(), lr = learning_rate)
#       3 criterion = nn.CrossEntropyLoss()
#
# NameError: name 'CNN' is not defined

# %%
print(model)

# %%
model.train()
i=0
for epoch in range(epoch_num):
  for data, target in train_loader:
    data = data.to(device)
    target = target.to(device)
    optimizer.zero_grad()
    output = model(data)
    loss = criterion(output, target)
    loss.backward()
    optimizer.step()
    if i % 1000 == 0:
      print(f"Train step: {i}\tLoss: {loss.item():.3f}")
    i += 1

# %%
model.eval()
correct = 0
for data, target in test_loader:
  data = data.to(device)
  target = target.to(device)
  output = model(data)
  prediction = output.data.max(1)[1]
  correct += prediction.eq(target.data).sum()

# %%
output.data.max(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-9f61a449fd27> in <cell line: 1>()
# ----> 1 output.data.max(1)
#
# NameError: name 'output' is not defined

# %%
prediction.eq(target.data).sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-f963e7b2bf75> in <cell line: 1>()
# ----> 1 prediction.eq(target.data).sum()
#
# NameError: name 'prediction' is not defined

# %%
prediction
# Out:
# tensor([4, 4, 8, 7, 3, 6, 3, 1, 3, 2, 5, 9, 8, 8, 9, 2, 6, 7, 4, 2, 1, 1, 9, 7,
#         6, 5, 9, 4, 6, 1, 1, 4, 0, 2, 1, 4, 5, 9, 1, 4, 2, 9, 0, 4, 0, 2, 3, 4,
#         2, 2], device='cuda:0')

# %%
print('Test set: Accuracy: {:.2f}%'.format(100. * correct / len(test_loader.dataset)))
# Out:
# Test set: Accuracy: 98.98%

# %%
torch.save(model.state_dict(), root_dir+'/mnist_model.pth')

# %%
from PIL import Image
from torchvision import transforms
import torchvision.transforms.functional as TF

# %%
def preprocess_image(img_path):
    print(img_path)
    image = Image.open(img_path)

    return image

# %%
preprocess_image(root_dir + '/data/myimg/0.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8ffbbd1087f3> in <cell line: 1>()
# ----> 1 preprocess_image(root_dir + '/data/myimg/0.png')
#
# NameError: name 'preprocess_image' is not defined
